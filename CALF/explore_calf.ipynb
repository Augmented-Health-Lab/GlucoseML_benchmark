# %%
# !pip install -r new_requirement.txt

# %%
# !python pca.py

# %% [markdown]
# ## Using context length = 144

# %%
# !python run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --model CALF \
  --model_id glucose_train \
  --data Glucose \
  --root_path /content/drive/Shareddrives/Baiying/preprocessed_dataset/training_dataset/mixed \
  --features S \
  --target BGvalue \
  --freq 5min \
  --d_model 768 \
  --n_heads 12 \
  --seq_len 144 \
  --label_len 72 \
  --pred_len 18 \
  --enc_in 1 \
  --dec_in 1 \
  --c_out 1 \
  --stride 1 \
  --batch_size 8 \
  --gpt_layers 4 \
  --train_epochs 30 \
  --patience 8 \
  --stride 12 \
  --learning_rate 1e-4 \
  --scale_value 1.0 \
  --max_windows_per_epoch 30000 \
  --num_workers 2 \
  --use_gpu 1 \
  --per_subject_eval 0

# %%
# !python run.py \
  --task_name long_term_forecast \
  --is_training 0 \
  --model CALF \
  --model_id glucose_train \
  --data Glucose \
  --root_path /unused/during/test \
  --test_root_path /content/drive/Shareddrives/Baiying/preprocessed_dataset/test_dataset/mixed \
  --features S \
  --checkpoints ./checkpoints \
  --seq_len 144 \
  --label_len 72 \
  --pred_len 18 \
  --d_model 768 \
  --n_heads 12 \
  --gpt_layers 4 \
  --batch_size 32 \
  --stride 1 \
  --scale_value 1.0

# %%
# !python run.py \
  --task_name long_term_forecast \
  --is_training 0 \
  --model CALF \
  --model_id glucose_train \
  --data Glucose \
  --root_path /unused/during/test \
  --test_root_path /content/drive/Shareddrives/Baiying/preprocessed_dataset/test_dataset/controlled_datasets/5_T1DEXI \
  --features S \
  --checkpoints ./checkpoints \
  --seq_len 144 \
  --label_len 72 \
  --pred_len 18 \
  --d_model 768 \
  --n_heads 12 \
  --gpt_layers 4 \
  --batch_size 32 \
  --stride 1 \
  --scale_value 1.0
